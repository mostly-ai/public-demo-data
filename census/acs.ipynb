# %%
import numpy as np
import pandas as pd
import re
import folktables
from folktables import ACSDataSource, ACSIncome, ACSEmployment, ACSHealthInsurance, ACSPublicCoverage

# %% [markdown]
# # US Census 2018

# %%
src = ACSDataSource(survey_year='2018', horizon='1-Year', survey='person')
defs = src.get_definitions()

# %%
cols = defs.groupby(1).first().reset_index().iloc[:,[0, 4]]
cols.columns = ['code', 'label']
cols.label = cols.label.apply(lambda x: re.sub('[ ]+[\(\,].*', '', x))
cols = {row.code: row.label for _, row in cols.iterrows()}
cols = cols | {
    'AGEP': 'Age',
    'COW': 'Workclass',
    'SCHL': 'Education',
    'MAR': 'Marital Status',
    'OCCP': 'Occupation',
    'WKHP': 'Hours per Week',
    'SEX': 'Gender',
    'RAC1P': 'Race',
    'PINCP': 'Income',
}

# %% [markdown]
# ## Income

# %%
dfs = []
for state in folktables.state_list:
    data = src.get_data(states=[state])
    cats = folktables.generate_categories(features=ACSIncome.features, definition_df=defs)
    X_state, y_state, _ = ACSIncome.df_to_pandas(data, categories=cats)
    df_state = pd.concat([X_state, y_state], axis=1)
    df_state.insert(0, "State", state)
    dfs.append(df_state)
df = pd.concat(dfs, axis=0).reset_index(drop=True)
df = df.rename(columns=cols)
df.to_parquet('acs-income-2018.parquet', index=False)
df
# Out:
#         State Age                                          Workclass  \
# 0          AL  18  Employee of a private for-profit company or bu...
# 1          AL  53                        Federal government employee
# 2          AL  41  Employee of a private for-profit company or bu...
# 3          AL  18  Self-employed in own not incorporated business...
# 4          AL  21                        Federal government employee
# ...       ...  ..                                                ...
# 1664495    PR  39  Self-employed in own not incorporated business...
# 1664496    PR  38  Self-employed in own not incorporated business...
# 1664497    PR  37  Employee of a private for-profit company or bu...
# 1664498    PR  47  Employee of a private for-profit company or bu...
# 1664499    PR  34  Employee of a private for-profit company or bu...
#
#                                             Education  \
# 0                  Some college, but less than 1 year
# 1                       GED or alternative credential
# 2                         Regular high school diploma
# 3                  Some college, but less than 1 year
# 4        1 or more years of college credit, no degree
# ...                                               ...
# 1664495                   Regular high school diploma
# 1664496                                      Grade 11
# 1664497  1 or more years of college credit, no degree
# 1664498                   Regular high school diploma
# 1664499                   Regular high school diploma
#
#                               Marital Status  \
# 0        Never married or under 15 years old
# 1        Never married or under 15 years old
# 2        Never married or under 15 years old
# 3        Never married or under 15 years old
# 4        Never married or under 15 years old
# ...                                      ...
# 1664495  Never married or under 15 years old
# 1664496  Never married or under 15 years old
# 1664497                             Divorced
# 1664498                              Married
# 1664499  Never married or under 15 years old
#
#                                                 Occupation Place of birth  \
# 0                                             SAL-Cashiers     Georgia/GA
# 1                      HLS-Orderlies and Psychiatric Aides     Indiana/IN
# 2        RPR-Industrial And Refractory Machinery Mechanics     Alabama/AL
# 3                                   ENT-Coaches and Scouts     Alabama/AL
# 4                                      PRT-Police Officers     Florida/FL
# ...                                                    ...            ...
# 1664495                          CON-Construction Laborers    Puerto Rico
# 1664496         CLN-Landscaping And Groundskeeping Workers    Puerto Rico
# 1664497               PRD-Other Assemblers And Fabricators    Illinois/IL
# 1664498  PRD-Miscellaneous Production Workers, Includin...    Puerto Rico
# 1664499                          CON-Construction Laborers    Puerto Rico
#
#                                            Relationship Hours per Week  \
# 0        Noninstitutionalized group quarters population           21.0
# 1           Institutionalized group quarters population           40.0
# 2        Noninstitutionalized group quarters population           40.0
# 3        Noninstitutionalized group quarters population            2.0
# 4        Noninstitutionalized group quarters population           50.0
# ...                                                 ...            ...
# 1664495                                Reference person           20.0
# 1664496                                Reference person           32.0
# 1664497                               Unmarried partner           40.0
# 1664498                                    Husband/wife           40.0
# 1664499                      Biological son or daughter           40.0
#
#          Gender                             Race  Income
# 0        Female  Black or African American alone   False
# 1          Male                      White alone   False
# 2          Male                      White alone   False
# 3        Female                      White alone   False
# 4          Male                      White alone   False
# ...         ...                              ...     ...
# 1664495    Male                      White alone   False
# 1664496    Male            Some Other Race alone   False
# 1664497  Female                Two or More Races   False
# 1664498    Male            Some Other Race alone   False
# 1664499    Male                      White alone   False
#
# [1664500 rows x 12 columns]

# %% [markdown]
# ## Employment

# %%
dfs = []
src = ACSDataSource(survey_year='2018', horizon='1-Year', survey='person')
defs = src.get_definitions()
for state in folktables.state_list:
    data = src.get_data(states=[state])
    cats = folktables.generate_categories(features=ACSEmployment.features, definition_df=defs)
    X_state, y_state, _ = ACSEmployment.df_to_pandas(data, categories=cats)
    df_state = pd.concat([X_state, y_state], axis=1)
    df_state.insert(0, "State", state)
    dfs.append(df_state)
df = pd.concat(dfs, axis=0).reset_index(drop=True)
df = df.rename(columns=cols)
df.to_parquet('acs-employment-2018.parquet', index=False)
df
# Out:
#         State Age                                     Education  \
# 0          AL  19            Some college, but less than 1 year
# 1          AL  18            Some college, but less than 1 year
# 2          AL  53                 GED or alternative credential
# 3          AL  28  1 or more years of college credit, no degree
# 4          AL  25                                       Grade 9
# ...       ...  ..                                           ...
# 3236102    PR  47                   Regular high school diploma
# 3236103    PR  18  1 or more years of college credit, no degree
# 3236104    PR  57                            Associate's degree
# 3236105    PR  66                                       Grade 9
# 3236106    PR  34                   Regular high school diploma
#
#                               Marital Status  \
# 0        Never married or under 15 years old
# 1        Never married or under 15 years old
# 2        Never married or under 15 years old
# 3        Never married or under 15 years old
# 4        Never married or under 15 years old
# ...                                      ...
# 3236102                              Married
# 3236103  Never married or under 15 years old
# 3236104                              Married
# 3236105                              Married
# 3236106  Never married or under 15 years old
#
#                                            Relationship     Disability recode  \
# 0        Noninstitutionalized group quarters population  Without a disability
# 1        Noninstitutionalized group quarters population  Without a disability
# 2           Institutionalized group quarters population     With a disability
# 3           Institutionalized group quarters population  Without a disability
# 4           Institutionalized group quarters population     With a disability
# ...                                                 ...                   ...
# 3236102                                    Husband/wife  Without a disability
# 3236103                      Biological son or daughter  Without a disability
# 3236104                                Reference person  Without a disability
# 3236105                                    Husband/wife  Without a disability
# 3236106                      Biological son or daughter  Without a disability
#
#                               Employment status of parents  \
# 0        N/A (not own child of householder, and not chi...
# 1        N/A (not own child of householder, and not chi...
# 2        N/A (not own child of householder, and not chi...
# 3        N/A (not own child of householder, and not chi...
# 4        N/A (not own child of householder, and not chi...
# ...                                                    ...
# 3236102  N/A (not own child of householder, and not chi...
# 3236103  N/A (not own child of householder, and not chi...
# 3236104  N/A (not own child of householder, and not chi...
# 3236105  N/A (not own child of householder, and not chi...
# 3236106  N/A (not own child of householder, and not chi...
#
#                                         Citizenship status  \
# 0                                         Born in the U.S.
# 1                                         Born in the U.S.
# 2                                         Born in the U.S.
# 3                                         Born in the U.S.
# 4                                         Born in the U.S.
# ...                                                    ...
# 3236102  Born in Puerto Rico, Guam, the U.S. Virgin Isl...
# 3236103  Born in Puerto Rico, Guam, the U.S. Virgin Isl...
# 3236104  Born in Puerto Rico, Guam, the U.S. Virgin Isl...
# 3236105  Born in Puerto Rico, Guam, the U.S. Virgin Isl...
# 3236106  Born in Puerto Rico, Guam, the U.S. Virgin Isl...
#
#                                   Mobility status  \
# 0        No, different house in US or Puerto Rico
# 1        No, different house in US or Puerto Rico
# 2                     Yes, same house (nonmovers)
# 3                     Yes, same house (nonmovers)
# 4        No, different house in US or Puerto Rico
# ...                                           ...
# 3236102               Yes, same house (nonmovers)
# 3236103               Yes, same house (nonmovers)
# 3236104               Yes, same house (nonmovers)
# 3236105               Yes, same house (nonmovers)
# 3236106  No, different house in US or Puerto Rico
#
#                                 Military service Ancestry recode Nativity  \
# 0                   Never served in the military          Single   Native
# 1                   Never served in the military          Single   Native
# 2                   Never served in the military        Multiple   Native
# 3        On active duty in the past, but not now          Single   Native
# 4                   Never served in the military          Single   Native
# ...                                          ...             ...      ...
# 3236102             Never served in the military          Single   Native
# 3236103             Never served in the military          Single   Native
# 3236104             Never served in the military          Single   Native
# 3236105             Never served in the military          Single   Native
# 3236106             Never served in the military          Single   Native
#
#         Hearing difficulty Vision difficulty Cognitive difficulty  Gender  \
# 0                       No                No                   No  Female
# 1                       No                No                   No  Female
# 2                       No                No                  Yes    Male
# 3                       No                No                   No    Male
# 4                       No                No                  Yes  Female
# ...                    ...               ...                  ...     ...
# 3236102                 No                No                   No    Male
# 3236103                 No                No                   No  Female
# 3236104                 No                No                   No  Female
# 3236105                 No                No                   No    Male
# 3236106                 No                No                   No    Male
#
#                                     Race  Employment status recode
# 0                            White alone                     False
# 1        Black or African American alone                     False
# 2                            White alone                     False
# 3                            White alone                     False
# 4                            White alone                     False
# ...                                  ...                       ...
# 3236102            Some Other Race alone                      True
# 3236103            Some Other Race alone                     False
# 3236104                      White alone                     False
# 3236105                      White alone                     False
# 3236106                      White alone                     False
#
# [3236107 rows x 18 columns]

# %% [markdown]
# ## Public Coverage

# %%
dfs = []
src = ACSDataSource(survey_year='2018', horizon='1-Year', survey='person')
defs = src.get_definitions()
for state in folktables.state_list:
    data = src.get_data(states=[state])
    cats = folktables.generate_categories(features=ACSPublicCoverage.features, definition_df=defs)
    X_state, y_state, _ = ACSPublicCoverage.df_to_pandas(data, categories=cats)
    df_state = pd.concat([X_state, y_state], axis=1)
    df_state.insert(0, "state", state)
    dfs.append(df_state)
df = pd.concat(dfs, axis=0).reset_index(drop=True)
df = df.rename(columns=cols)
df.to_parquet('acs-publiccoverage-2018.parquet', index=False)
df
# Out:
#         state Age                                     Education  \
# 0          AL  19            Some college, but less than 1 year
# 1          AL  18            Some college, but less than 1 year
# 2          AL  53                 GED or alternative credential
# 3          AL  28  1 or more years of college credit, no degree
# 4          AL  25                                       Grade 9
# ...       ...  ..                                           ...
# 1138284    PR  47                             Bachelor's degree
# 1138285    PR  47                   Regular high school diploma
# 1138286    PR  18  1 or more years of college credit, no degree
# 1138287    PR  57                            Associate's degree
# 1138288    PR  34                   Regular high school diploma
#
#                               Marital Status  Gender     Disability recode  \
# 0        Never married or under 15 years old  Female  Without a disability
# 1        Never married or under 15 years old  Female  Without a disability
# 2        Never married or under 15 years old    Male     With a disability
# 3        Never married or under 15 years old    Male  Without a disability
# 4        Never married or under 15 years old  Female     With a disability
# ...                                      ...     ...                   ...
# 1138284                              Married  Female  Without a disability
# 1138285                              Married    Male  Without a disability
# 1138286  Never married or under 15 years old  Female  Without a disability
# 1138287                              Married  Female  Without a disability
# 1138288  Never married or under 15 years old    Male  Without a disability
#
#                               Employment status of parents  \
# 0        N/A (not own child of householder, and not chi...
# 1        N/A (not own child of householder, and not chi...
# 2        N/A (not own child of householder, and not chi...
# 3        N/A (not own child of householder, and not chi...
# 4        N/A (not own child of householder, and not chi...
# ...                                                    ...
# 1138284  N/A (not own child of householder, and not chi...
# 1138285  N/A (not own child of householder, and not chi...
# 1138286  N/A (not own child of householder, and not chi...
# 1138287  N/A (not own child of householder, and not chi...
# 1138288  N/A (not own child of householder, and not chi...
#
#                                         Citizenship status  \
# 0                                         Born in the U.S.
# 1                                         Born in the U.S.
# 2                                         Born in the U.S.
# 3                                         Born in the U.S.
# 4                                         Born in the U.S.
# ...                                                    ...
# 1138284                                   Born in the U.S.
# 1138285  Born in Puerto Rico, Guam, the U.S. Virgin Isl...
# 1138286  Born in Puerto Rico, Guam, the U.S. Virgin Isl...
# 1138287  Born in Puerto Rico, Guam, the U.S. Virgin Isl...
# 1138288  Born in Puerto Rico, Guam, the U.S. Virgin Isl...
#
#                                   Mobility status  \
# 0        No, different house in US or Puerto Rico
# 1        No, different house in US or Puerto Rico
# 2                     Yes, same house (nonmovers)
# 3                     Yes, same house (nonmovers)
# 4        No, different house in US or Puerto Rico
# ...                                           ...
# 1138284               Yes, same house (nonmovers)
# 1138285               Yes, same house (nonmovers)
# 1138286               Yes, same house (nonmovers)
# 1138287               Yes, same house (nonmovers)
# 1138288  No, different house in US or Puerto Rico
#
#                                 Military service  ... Nativity  \
# 0                   Never served in the military  ...   Native
# 1                   Never served in the military  ...   Native
# 2                   Never served in the military  ...   Native
# 3        On active duty in the past, but not now  ...   Native
# 4                   Never served in the military  ...   Native
# ...                                          ...  ...      ...
# 1138284             Never served in the military  ...   Native
# 1138285             Never served in the military  ...   Native
# 1138286             Never served in the military  ...   Native
# 1138287             Never served in the military  ...   Native
# 1138288             Never served in the military  ...   Native
#
#         Hearing difficulty Vision difficulty Cognitive difficulty   Income  \
# 0                       No                No                   No  -1500.0
# 1                       No                No                   No   1600.0
# 2                       No                No                  Yes  10000.0
# 3                       No                No                   No      0.0
# 4                       No                No                  Yes      0.0
# ...                    ...               ...                  ...      ...
# 1138284                 No                No                   No  16400.0
# 1138285                 No                No                   No  18700.0
# 1138286                 No                No                   No      0.0
# 1138287                 No                No                   No  11100.0
# 1138288                 No                No                   No   7900.0
#
#            Employment status recode  \
# 0                Not in labor force
# 1                Not in labor force
# 2                Not in labor force
# 3                Not in labor force
# 4                Not in labor force
# ...                             ...
# 1138284          Not in labor force
# 1138285  Civilian employed, at work
# 1138286          Not in labor force
# 1138287          Not in labor force
# 1138288                  Unemployed
#
#         State Code based on 2010 Census definitions  \
# 0                                        Alabama/AL
# 1                                        Alabama/AL
# 2                                        Alabama/AL
# 3                                        Alabama/AL
# 4                                        Alabama/AL
# ...                                             ...
# 1138284                              Puerto Rico/PR
# 1138285                              Puerto Rico/PR
# 1138286                              Puerto Rico/PR
# 1138287                              Puerto Rico/PR
# 1138288                              Puerto Rico/PR
#
#              Gave birth to child within the past 12 months  \
# 0                                                       No
# 1                                                       No
# 2        N/A (less than 15 years/greater than 50 years/...
# 3        N/A (less than 15 years/greater than 50 years/...
# 4                                                       No
# ...                                                    ...
# 1138284                                                 No
# 1138285  N/A (less than 15 years/greater than 50 years/...
# 1138286                                                 No
# 1138287  N/A (less than 15 years/greater than 50 years/...
# 1138288  N/A (less than 15 years/greater than 50 years/...
#
#                                     Race Public health coverage recode
# 0                            White alone                         False
# 1        Black or African American alone                         False
# 2                            White alone                         False
# 3                            White alone                         False
# 4                            White alone                         False
# ...                                  ...                           ...
# 1138284            Some Other Race alone                         False
# 1138285            Some Other Race alone                         False
# 1138286            Some Other Race alone                         False
# 1138287                      White alone                          True
# 1138288                      White alone                         False
#
# [1138289 rows x 21 columns]
